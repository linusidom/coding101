# %% [markdown]
# # Pandas Importing Exporting Data Exercises

# %%
# Import pandas as pd and numpy as np

import pandas as pd
import numpy as np

# Type your code above this line

# %%
# Import the Excel Spreadsheet 'Import Export Exercises.xlsx' into a dataframe

df = pd.read_excel('Import Export Exercises.xlsx')

# Fill in the Nan values with 'h'
df = df.fillna('h')

# Change the index to be the column with Row1-Row4
df = df.set_index('Unnamed: 0')

# Change the name of the column to be 'Rows'
df.index.names = ['Rows']

df




# Type your code above this line
# Out:
#      Column1 Column2 Column3 Column4
# Rows
# Row1       a       b       a       b
# Row2       c       d       c       d
# Row3       e       f       e       f
# Row4       g       h       g       h

# %%
# Out:
#   Unnamed: 0 Column1 Column2 Column3 Column4
# 0       Row1       a       b       a       b
# 1       Row2       c       d       c       d
# 2       Row3       e       f       e       f
# 3       Row4       g     NaN       g     NaN

# %%
# Import the following dataset from Kaggle (https://www.kaggle.com/datasets/jealousleopard/goodreadsbooks)

# Warning: You will get errors - Google how to fix them or look for another Kaggle Article on the GoodReads Dataset

df = pd.read_csv('books.csv', on_bad_lines='warn')
df.head()
# How many entries are in our dataset?
# 11123

# How many columns are in our dataset?
# 12

# What is the 'mean' rating for all the books in our dataset?
# df['average_rating'].mean()
df.describe()


df[df['average_rating'] == 5.0]






# Type your code above this line
# Out:
# b'Skipping line 3350: expected 12 fields, saw 13\nSkipping line 4704: expected 12 fields, saw 13\nSkipping line 5879: expected 12 fields, saw 13\nSkipping line 8981: expected 12 fields, saw 13\n'
#        bookID                                              title  \
# 624      2034  Comoediae 1: Acharenses/Equites/Nubes/Vespae/P...
# 786      2560                  Willem de Kooning: Late Paintings
# 855      2843  Literature Circle Guide: Bridge to Terabithia:...
# 1243     4287  Middlesex Borough (Images of America: New Jersey)
# 4125    14741  Zone of the Enders: The 2nd Runner Official St...
# 4788    17224  The Diamond Color Meditation: Color Pathway to...
# 4933    17830  Bulgakov's the Master and Margarita: The Text ...
# 5023    18184  The Complete Theory Fun Factory: Music Theory ...
# 5474    19786  The Goon Show  Volume 4: My Knees Have Fallen ...
# 5476    19788  The Goon Show  Volume 11: He's Fallen in the W...
# ...

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11123 entries, 0 to 11122
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   bookID              11123 non-null  int64
#  1   title               11123 non-null  object
#  2   authors             11123 non-null  object
#  3   average_rating      11123 non-null  float64
#  4   isbn                11123 non-null  object
#  5   isbn13              11123 non-null  int64
#  6   language_code       11123 non-null  object
#  7     num_pages         11123 non-null  int64
#  8   ratings_count       11123 non-null  int64
#  9   text_reviews_count  11123 non-null  int64
#  10  publication_date    11123 non-null  object
#  11  publisher           11123 non-null  object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 1.0+ MB
# None
#              bookID  average_rating        isbn13     num_pages  \
# ...
