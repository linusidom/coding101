# %% [markdown]
# # Functions Cheat Sheet (Advanced)
#
#
# ### *args
# `
# def name_of_function(*args):
#     return args
# `
#
# Example Sum Function:
# `
# def sum(*args):
#     total = 0
#     for arg in args:
#         total += arg
#     return total
# `
#
#
# ### **kwargs
# `
# def name_of_function(**kwargs):
#     return kwargs
# `
#
# Example Sum Function:
# `
# def sum(**kwargs):
#     total = 0
#     for kw in kwargs:
#         total += kwargs[kw]
#     return total
# `
#
#
# ### Lambda Functions
# Quick way to write functions in a single line
#
# Standard Function
# `
# def my_sum(num1, num2):
#     return num1 + num2
# `
#
# Lambda Expression
# `my_sum = lambda num1, num2: num1 + num2`
#
# Calling both functions is the exact same
#
# `
# my_sum(1,2) => 3
# `
#
# ### Recursion (more for advanced algorithms but good to know)
# A while loop but for Functions
#
# Very Complicated to understand but very concisce in code
#
# Can be very fast with incrementing / decrementing
#
# Increment Example
# `
# def nat_sum (n):
#     if n <= 0:
#         return n
#     else:
#         return n + nat_sum (n-1)
# `
#
# Decrement Example
# `
# def nat_sub(n):
#     if n <= 0:
#         return n
#     else:
#         return n - nat_sub(n-1)
# `
#
#
#
#
#
#
# ### Exporting Functions or rather Importing
# All variables, functions and classes within python are importable (automatically exported)
#
# Conditionals and loops are not exported therefore no importable
# However we can "wrap" conditionals and loops inside a function and then import it elsewhere
#
# `
# from file import function
# from file.file import function
# `

# %%
def my_sum(num1, num2):
    return num1 + num2

# %%
my_sum(1,2,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [55], in <cell line: 1>()
# ----> 1 my_sum(1,2,3)
#
# TypeError: my_sum() takes 2 positional arguments but 3 were given

# %%
# def my_arg_sum(*args):
#     print('Arguments:',args)
#     return sum(args)

# def function(positional arguments, unnamed arguments in list/tuple, keyword arguments )

def my_arg_sum(num1, *args):
    print('Postional Argument: ',num1)
    print('Arguments:', args)

# %%
my_arg_sum(1,2,3,4,5,6,7)
# Out:
# Postional Argument:  1
# Arguments: (2, 3, 4, 5, 6, 7)

# %%
def my_kwarg_sum(**kwargs):
    print('Keyword Arguments:',kwargs)
#     print('Get Response:', kwargs.get('c', None))
    total = 0
    for value in kwargs.values():
        total += value
    return total
    
    
my_kwarg_sum(a=1,b=2, c=3, d=4,e=5)
# Out:
# Keyword Arguments: {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5}
# 15

# %%
# '*' -> Argument in a tuple
# '**' -> Keyword Argument in a dictionary

# def function(arg, *args, **kwargs)

def my_sum(arg, *args, **kwargs):
    total = 0
    print('Argument:',arg)
#     Arg addition
    total += arg
    
#     *args addition
    print('Arguments:',args)
    for arg in args:
        total += arg
    
#     **kwarg addition
    print('KW Arguments:',kwargs)
    for arg in kwargs.values():
        total += arg
    
    return total

# If we have a positional arguments we have to include an equal amout of arguments in our function
my_sum(1)
# Out:
# Argument: 1
# Arguments: ()
# KW Arguments: {}
# 1

# %%
# Syntactical Sugar -> Does the same thing but looks much sweeter!

# def my_function(x, y):
#     return x * 2

my_function = lambda x,y: x * y

my_function(6,7)
# Out:
# 42

# %%
count = 0 # start case
while count < 5: # break condition
    count += 1 # step case
    print(count)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# Recursion

def my_recursive_sum(num): 
    if num <= 0:
        return num
    return num + my_recursive_sum(num - 1)

my_recursive_sum(5)


# In a function there is a stack of memory spaces

# 5 + my_recursive_sum(4) -> Stack 1
# 4 + my_recursive_sum(3) -> Stack 2
# 3 + my_recursive_sum(2) -> Stack 3
# 2 + my_recursive_sum(1) -> Stack 4
# 1 + my_recursive_sum(0) -> Stack 5

# Once we hit the break case we can move up the stack
# Stack 5 -> 1 + 0 -> 1
# Stack 4 -> 2 + 1 -> 3
# Stack 3 -> 3 + 3 -> 6
# Stack 2 -> 4 + 6 -> 10
# Stack 1 -> 5 + 10 -> 15

# Recursion is pointless with Sum or subtract function because it's easy to do those in a single memory stack
# But when it comes to real mathematics like factorials then recursion makes a lot of sense
# Plus it's a really common interview question so if you can map out the stack then you know how recursion works
# Out:
# 15

# %%
# This is a recursion Error

def my_sum_error(num):
    print('The number runs: ',num)
    
#     Remove this to fix maximum recursion depth error
#     if num <= 0:
#         return num
    return num + my_sum_error(num - 1)

my_sum_error(5)

# Error kept in on purpose to show maximum recursion depth error
# Out:
# The number runs:  5
# The number runs:  4
# The number runs:  3
# The number runs:  2
# The number runs:  1
# The number runs:  0
# The number runs:  -1
# The number runs:  -2
# The number runs:  -3
# The number runs:  -4
# The number runs:  -5
# The number runs:  -6
# The number runs:  -7
# The number runs:  -8
# The number runs:  -9
# The number runs:  -10
# The number runs:  -11
# The number runs:  -12
# The number runs:  -13
# The number runs:  -14
# The number runs:  -15
# The number runs:  -16
# The number runs:  -17
# The number runs:  -18
# The number runs:  -19
# The number runs:  -20
# The number runs:  -21
# The number runs:  -22
# The number runs:  -23
# The number runs:  -24
# The number runs:  -25
# The number runs:  -26
# The number runs:  -27
# The number runs:  -28
# The number runs:  -29
# The number runs:  -30
# The number runs:  -31
# The number runs:  -32
# The number runs:  -33
# The number runs:  -34
# The number runs:  -35
# The number runs:  -36
# The number runs:  -37
# The number runs:  -38
# The number runs:  -39
# The number runs:  -40
# The number runs:  -41
# The number runs:  -42
# The number runs:  -43
# The number runs:  -44
# The number runs:  -45
# The number runs:  -46
# The number runs:  -47
# The number runs:  -48
# The number runs:  -49
# The number runs:  -50
# The number runs:  -51
# The number runs:  -52
# The number runs:  -53
# The number runs:  -54
# The number runs:  -55
# The number runs:  -56
# The number runs:  -57
# The number runs:  -58
# The number runs:  -59
# The number runs:  -60
# The number runs:  -61
# The number runs:  -62
# The number runs:  -63
# The number runs:  -64
# The number runs:  -65
# The number runs:  -66
# The number runs:  -67
# The number runs:  -68
# The number runs:  -69
# The number runs:  -70
# The number runs:  -71
# The number runs:  -72
# The number runs:  -73
# The number runs:  -74
# The number runs:  -75
# The number runs:  -76
# The number runs:  -77
# The number runs:  -78
# The number runs:  -79
# The number runs:  -80
# The number runs:  -81
# The number runs:  -82
# The number runs:  -83
# The number runs:  -84
# The number runs:  -85
# The number runs:  -86
# The number runs:  -87
# The number runs:  -88
# The number runs:  -89
# The number runs:  -90
# The number runs:  -91
# The number runs:  -92
# The number runs:  -93
# The number runs:  -94
# The number runs:  -95
# The number runs:  -96
# The number runs:  -97
# The number runs:  -98
# The number runs:  -99
# The number runs:  -100
# The number runs:  -101
# The number runs:  -102
# The number runs:  -103
# The number runs:  -104
# The number runs:  -105
# The number runs:  -106
# The number runs:  -107
# The number runs:  -108
# The number runs:  -109
# The number runs:  -110
# The number runs:  -111
# The number runs:  -112
# The number runs:  -113
# The number runs:  -114
# The number runs:  -115
# The number runs:  -116
# The number runs:  -117
# The number runs:  -118
# The number runs:  -119
# The number runs:  -120
# The number runs:  -121
# The number runs:  -122
# The number runs:  -123
# The number runs:  -124
# The number runs:  -125
# The number runs:  -126
# The number runs:  -127
# The number runs:  -128
# The number runs:  -129
# The number runs:  -130
# The number runs:  -131
# The number runs:  -132
# The number runs:  -133
# The number runs:  -134
# The number runs:  -135
# The number runs:  -136
# The number runs:  -137
# The number runs:  -138
# The number runs:  -139
# The number runs:  -140
# The number runs:  -141
# The number runs:  -142
# The number runs:  -143
# The number runs:  -144
# The number runs:  -145
# The number runs:  -146
# The number runs:  -147
# The number runs:  -148
# The number runs:  -149
# The number runs:  -150
# The number runs:  -151
# The number runs:  -152
# The number runs:  -153
# The number runs:  -154
# The number runs:  -155
# The number runs:  -156
# The number runs:  -157
# The number runs:  -158
# The number runs:  -159
# The number runs:  -160
# The number runs:  -161
# The number runs:  -162
# The number runs:  -163
# The number runs:  -164
# The number runs:  -165
# The number runs:  -166
# The number runs:  -167
# The number runs:  -168
# The number runs:  -169
# The number runs:  -170
# The number runs:  -171
# The number runs:  -172
# The number runs:  -173
# The number runs:  -174
# The number runs:  -175
# The number runs:  -176
# The number runs:  -177
# The number runs:  -178
# The number runs:  -179
# The number runs:  -180
# The number runs:  -181
# The number runs:  -182
# The number runs:  -183
# The number runs:  -184
# The number runs:  -185
# The number runs:  -186
# The number runs:  -187
# The number runs:  -188
# The number runs:  -189
# The number runs:  -190
# The number runs:  -191
# The number runs:  -192
# The number runs:  -193
# The number runs:  -194
# The number runs:  -195
# The number runs:  -196
# The number runs:  -197
# The number runs:  -198
# The number runs:  -199
# The number runs:  -200
# The number runs:  -201
# The number runs:  -202
# The number runs:  -203
# The number runs:  -204
# The number runs:  -205
# The number runs:  -206
# The number runs:  -207
# The number runs:  -208
# The number runs:  -209
# The number runs:  -210
# The number runs:  -211
# The number runs:  -212
# The number runs:  -213
# The number runs:  -214
# The number runs:  -215
# The number runs:  -216
# The number runs:  -217
# The number runs:  -218
# The number runs:  -219
# The number runs:  -220
# The number runs:  -221
# The number runs:  -222
# The number runs:  -223
# The number runs:  -224
# The number runs:  -225
# The number runs:  -226
# The number runs:  -227
# The number runs:  -228
# The number runs:  -229
# The number runs:  -230
# The number runs:  -231
# The number runs:  -232
# The number runs:  -233
# The number runs:  -234
# The number runs:  -235
# The number runs:  -236
# The number runs:  -237
# The number runs:  -238
# The number runs:  -239
# The number runs:  -240
# The number runs:  -241
# The number runs:  -242
# The number runs:  -243
# The number runs:  -244
# The number runs:  -245
# The number runs:  -246
# The number runs:  -247
# The number runs:  -248
# The number runs:  -249
# The number runs:  -250
# The number runs:  -251
# The number runs:  -252
# The number runs:  -253
# The number runs:  -254
# The number runs:  -255
# The number runs:  -256
# The number runs:  -257
# The number runs:  -258
# The number runs:  -259
# The number runs:  -260
# The number runs:  -261
# The number runs:  -262
# The number runs:  -263
# The number runs:  -264
# The number runs:  -265
# The number runs:  -266
# The number runs:  -267
# The number runs:  -268
# The number runs:  -269
# The number runs:  -270
# The number runs:  -271
# The number runs:  -272
# The number runs:  -273
# The number runs:  -274
# The number runs:  -275
# The number runs:  -276
# The number runs:  -277
# The number runs:  -278
# The number runs:  -279
# The number runs:  -280
# The number runs:  -281
# The number runs:  -282
# The number runs:  -283
# The number runs:  -284
# The number runs:  -285
# The number runs:  -286
# The number runs:  -287
# The number runs:  -288
# The number runs:  -289
# The number runs:  -290
# The number runs:  -291
# The number runs:  -292
# The number runs:  -293
# The number runs:  -294
# The number runs:  -295
# The number runs:  -296
# The number runs:  -297
# The number runs:  -298
# The number runs:  -299
# The number runs:  -300
# The number runs:  -301
# The number runs:  -302
# The number runs:  -303
# The number runs:  -304
# The number runs:  -305
# The number runs:  -306
# The number runs:  -307
# The number runs:  -308
# The number runs:  -309
# The number runs:  -310
# The number runs:  -311
# The number runs:  -312
# The number runs:  -313
# The number runs:  -314
# The number runs:  -315
# The number runs:  -316
# The number runs:  -317
# The number runs:  -318
# The number runs:  -319
# The number runs:  -320
# The number runs:  -321
# The number runs:  -322
# The number runs:  -323
# The number runs:  -324
# The number runs:  -325
# The number runs:  -326
# The number runs:  -327
# The number runs:  -328
# The number runs:  -329
# The number runs:  -330
# The number runs:  -331
# The number runs:  -332
# The number runs:  -333
# The number runs:  -334
# The number runs:  -335
# The number runs:  -336
# The number runs:  -337
# The number runs:  -338
# The number runs:  -339
# The number runs:  -340
# The number runs:  -341
# The number runs:  -342
# The number runs:  -343
# The number runs:  -344
# The number runs:  -345
# The number runs:  -346
# The number runs:  -347
# The number runs:  -348
# The number runs:  -349
# The number runs:  -350
# The number runs:  -351
# The number runs:  -352
# The number runs:  -353
# The number runs:  -354
# The number runs:  -355
# The number runs:  -356
# The number runs:  -357
# The number runs:  -358
# The number runs:  -359
# The number runs:  -360
# The number runs:  -361
# The number runs:  -362
# The number runs:  -363
# The number runs:  -364
# The number runs:  -365
# The number runs:  -366
# The number runs:  -367
# The number runs:  -368
# The number runs:  -369
# The number runs:  -370
# The number runs:  -371
# The number runs:  -372
# The number runs:  -373
# The number runs:  -374
# The number runs:  -375
# The number runs:  -376
# The number runs:  -377
# The number runs:  -378
# The number runs:  -379
# The number runs:  -380
# The number runs:  -381
# The number runs:  -382
# The number runs:  -383
# The number runs:  -384
# The number runs:  -385
# The number runs:  -386
# The number runs:  -387
# The number runs:  -388
# The number runs:  -389
# The number runs:  -390
# The number runs:  -391
# The number runs:  -392
# The number runs:  -393
# The number runs:  -394
# The number runs:  -395
# The number runs:  -396
# The number runs:  -397
# The number runs:  -398
# The number runs:  -399
# The number runs:  -400
# The number runs:  -401
# The number runs:  -402
# The number runs:  -403
# The number runs:  -404
# The number runs:  -405
# The number runs:  -406
# The number runs:  -407
# The number runs:  -408
# The number runs:  -409
# The number runs:  -410
# The number runs:  -411
# The number runs:  -412
# The number runs:  -413
# The number runs:  -414
# The number runs:  -415
# The number runs:  -416
# The number runs:  -417
# The number runs:  -418
# The number runs:  -419
# The number runs:  -420
# The number runs:  -421
# The number runs:  -422
# The number runs:  -423
# The number runs:  -424
# The number runs:  -425
# The number runs:  -426
# The number runs:  -427
# The number runs:  -428
# The number runs:  -429
# The number runs:  -430
# The number runs:  -431
# The number runs:  -432
# The number runs:  -433
# The number runs:  -434
# The number runs:  -435
# The number runs:  -436
# The number runs:  -437
# The number runs:  -438
# The number runs:  -439
# The number runs:  -440
# The number runs:  -441
# The number runs:  -442
# The number runs:  -443
# The number runs:  -444
# The number runs:  -445
# The number runs:  -446
# The number runs:  -447
# The number runs:  -448
# The number runs:  -449
# The number runs:  -450
# The number runs:  -451
# The number runs:  -452
# The number runs:  -453
# The number runs:  -454
# The number runs:  -455
# The number runs:  -456
# The number runs:  -457
# The number runs:  -458
# The number runs:  -459
# The number runs:  -460
# The number runs:  -461
# The number runs:  -462
# The number runs:  -463
# The number runs:  -464
# The number runs:  -465
# The number runs:  -466
# The number runs:  -467
# The number runs:  -468
# The number runs:  -469
# The number runs:  -470
# The number runs:  -471
# The number runs:  -472
# The number runs:  -473
# The number runs:  -474
# The number runs:  -475
# The number runs:  -476
# The number runs:  -477
# The number runs:  -478
# The number runs:  -479
# The number runs:  -480
# The number runs:  -481
# The number runs:  -482
# The number runs:  -483
# The number runs:  -484
# The number runs:  -485
# The number runs:  -486
# The number runs:  -487
# The number runs:  -488
# The number runs:  -489
# The number runs:  -490
# The number runs:  -491
# The number runs:  -492
# The number runs:  -493
# The number runs:  -494
# The number runs:  -495
# The number runs:  -496
# The number runs:  -497
# The number runs:  -498
# The number runs:  -499
# The number runs:  -500
# The number runs:  -501
# The number runs:  -502
# The number runs:  -503
# The number runs:  -504
# The number runs:  -505
# The number runs:  -506
# The number runs:  -507
# The number runs:  -508
# The number runs:  -509
# The number runs:  -510
# The number runs:  -511
# The number runs:  -512
# The number runs:  -513
# The number runs:  -514
# The number runs:  -515
# The number runs:  -516
# The number runs:  -517
# The number runs:  -518
# The number runs:  -519
# The number runs:  -520
# The number runs:  -521
# The number runs:  -522
# The number runs:  -523
# The number runs:  -524
# The number runs:  -525
# The number runs:  -526
# The number runs:  -527
# The number runs:  -528
# The number runs:  -529
# The number runs:  -530
# The number runs:  -531
# The number runs:  -532
# The number runs:  -533
# The number runs:  -534
# The number runs:  -535
# The number runs:  -536
# The number runs:  -537
# The number runs:  -538
# The number runs:  -539
# The number runs:  -540
# The number runs:  -541
# The number runs:  -542
# The number runs:  -543
# The number runs:  -544
# The number runs:  -545
# The number runs:  -546
# The number runs:  -547
# The number runs:  -548
# The number runs:  -549
# The number runs:  -550
# The number runs:  -551
# The number runs:  -552
# The number runs:  -553
# The number runs:  -554
# The number runs:  -555
# The number runs:  -556
# The number runs:  -557
# The number runs:  -558
# The number runs:  -559
# The number runs:  -560
# The number runs:  -561
# The number runs:  -562
# The number runs:  -563
# The number runs:  -564
# The number runs:  -565
# The number runs:  -566
# The number runs:  -567
# The number runs:  -568
# The number runs:  -569
# The number runs:  -570
# The number runs:  -571
# The number runs:  -572
# The number runs:  -573
# The number runs:  -574
# The number runs:  -575
# The number runs:  -576
# The number runs:  -577
# The number runs:  -578
# The number runs:  -579
# The number runs:  -580
# The number runs:  -581
# The number runs:  -582
# The number runs:  -583
# The number runs:  -584
# The number runs:  -585
# The number runs:  -586
# The number runs:  -587
# The number runs:  -588
# The number runs:  -589
# The number runs:  -590
# The number runs:  -591
# The number runs:  -592
# The number runs:  -593
# The number runs:  -594
# The number runs:  -595
# The number runs:  -596
# The number runs:  -597
# The number runs:  -598
# The number runs:  -599
# The number runs:  -600
# The number runs:  -601
# The number runs:  -602
# The number runs:  -603
# The number runs:  -604
# The number runs:  -605
# The number runs:  -606
# The number runs:  -607
# The number runs:  -608
# The number runs:  -609
# The number runs:  -610
# The number runs:  -611
# The number runs:  -612
# The number runs:  -613
# The number runs:  -614
# The number runs:  -615
# The number runs:  -616
# The number runs:  -617
# The number runs:  -618
# The number runs:  -619
# The number runs:  -620
# The number runs:  -621
# The number runs:  -622
# The number runs:  -623
# The number runs:  -624
# The number runs:  -625
# The number runs:  -626
# The number runs:  -627
# The number runs:  -628
# The number runs:  -629
# The number runs:  -630
# The number runs:  -631
# The number runs:  -632
# The number runs:  -633
# The number runs:  -634
# The number runs:  -635
# The number runs:  -636
# The number runs:  -637
# The number runs:  -638
# The number runs:  -639
# The number runs:  -640
# The number runs:  -641
# The number runs:  -642
# The number runs:  -643
# The number runs:  -644
# The number runs:  -645
# The number runs:  -646
# The number runs:  -647
# The number runs:  -648
# The number runs:  -649
# The number runs:  -650
# The number runs:  -651
# The number runs:  -652
# The number runs:  -653
# The number runs:  -654
# The number runs:  -655
# The number runs:  -656
# The number runs:  -657
# The number runs:  -658
# The number runs:  -659
# The number runs:  -660
# The number runs:  -661
# The number runs:  -662
# The number runs:  -663
# The number runs:  -664
# The number runs:  -665
# The number runs:  -666
# The number runs:  -667
# The number runs:  -668
# The number runs:  -669
# The number runs:  -670
# The number runs:  -671
# The number runs:  -672
# The number runs:  -673
# The number runs:  -674
# The number runs:  -675
# The number runs:  -676
# The number runs:  -677
# The number runs:  -678
# The number runs:  -679
# The number runs:  -680
# The number runs:  -681
# The number runs:  -682
# The number runs:  -683
# The number runs:  -684
# The number runs:  -685
# The number runs:  -686
# The number runs:  -687
# The number runs:  -688
# The number runs:  -689
# The number runs:  -690
# The number runs:  -691
# The number runs:  -692
# The number runs:  -693
# The number runs:  -694
# The number runs:  -695
# The number runs:  -696
# The number runs:  -697
# The number runs:  -698
# The number runs:  -699
# The number runs:  -700
# The number runs:  -701
# The number runs:  -702
# The number runs:  -703
# The number runs:  -704
# The number runs:  -705
# The number runs:  -706
# The number runs:  -707
# The number runs:  -708
# The number runs:  -709
# The number runs:  -710
# The number runs:  -711
# The number runs:  -712
# The number runs:  -713
# The number runs:  -714
# The number runs:  -715
# The number runs:  -716
# The number runs:  -717
# The number runs:  -718
# The number runs:  -719
# The number runs:  -720
# The number runs:  -721
# The number runs:  -722
# The number runs:  -723
# The number runs:  -724
# The number runs:  -725
# The number runs:  -726
# The number runs:  -727
# The number runs:  -728
# The number runs:  -729
# The number runs:  -730
# The number runs:  -731
# The number runs:  -732
# The number runs:  -733
# The number runs:  -734
# The number runs:  -735
# The number runs:  -736
# The number runs:  -737
# The number runs:  -738
# The number runs:  -739
# The number runs:  -740
# The number runs:  -741
# The number runs:  -742
# The number runs:  -743
# The number runs:  -744
# The number runs:  -745
# The number runs:  -746
# The number runs:  -747
# The number runs:  -748
# The number runs:  -749
# The number runs:  -750
# The number runs:  -751
# The number runs:  -752
# The number runs:  -753
# The number runs:  -754
# The number runs:  -755
# The number runs:  -756
# The number runs:  -757
# The number runs:  -758
# The number runs:  -759
# The number runs:  -760
# The number runs:  -761
# The number runs:  -762
# The number runs:  -763
# The number runs:  -764
# The number runs:  -765
# The number runs:  -766
# The number runs:  -767
# The number runs:  -768
# The number runs:  -769
# The number runs:  -770
# The number runs:  -771
# The number runs:  -772
# The number runs:  -773
# The number runs:  -774
# The number runs:  -775
# The number runs:  -776
# The number runs:  -777
# The number runs:  -778
# The number runs:  -779
# The number runs:  -780
# The number runs:  -781
# The number runs:  -782
# The number runs:  -783
# The number runs:  -784
# The number runs:  -785
# The number runs:  -786
# The number runs:  -787
# The number runs:  -788
# The number runs:  -789
# The number runs:  -790
# The number runs:  -791
# The number runs:  -792
# The number runs:  -793
# The number runs:  -794
# The number runs:  -795
# The number runs:  -796
# The number runs:  -797
# The number runs:  -798
# The number runs:  -799
# The number runs:  -800
# The number runs:  -801
# The number runs:  -802
# The number runs:  -803
# The number runs:  -804
# The number runs:  -805
# The number runs:  -806
# The number runs:  -807
# The number runs:  -808
# The number runs:  -809
# The number runs:  -810
# The number runs:  -811
# The number runs:  -812
# The number runs:  -813
# The number runs:  -814
# The number runs:  -815
# The number runs:  -816
# The number runs:  -817
# The number runs:  -818
# The number runs:  -819
# The number runs:  -820
# The number runs:  -821
# The number runs:  -822
# The number runs:  -823
# The number runs:  -824
# The number runs:  -825
# The number runs:  -826
# The number runs:  -827
# The number runs:  -828
# The number runs:  -829
# The number runs:  -830
# The number runs:  -831
# The number runs:  -832
# The number runs:  -833
# The number runs:  -834
# The number runs:  -835
# The number runs:  -836
# The number runs:  -837
# The number runs:  -838
# The number runs:  -839
# The number runs:  -840
# The number runs:  -841
# The number runs:  -842
# The number runs:  -843
# The number runs:  -844
# The number runs:  -845
# The number runs:  -846
# The number runs:  -847
# The number runs:  -848
# The number runs:  -849
# The number runs:  -850
# The number runs:  -851
# The number runs:  -852
# The number runs:  -853
# The number runs:  -854
# The number runs:  -855
# The number runs:  -856
# The number runs:  -857
# The number runs:  -858
# The number runs:  -859
# The number runs:  -860
# The number runs:  -861
# The number runs:  -862
# The number runs:  -863
# The number runs:  -864
# The number runs:  -865
# The number runs:  -866
# The number runs:  -867
# The number runs:  -868
# The number runs:  -869
# The number runs:  -870
# The number runs:  -871
# The number runs:  -872
# The number runs:  -873
# The number runs:  -874
# The number runs:  -875
# The number runs:  -876
# The number runs:  -877
# The number runs:  -878
# The number runs:  -879
# The number runs:  -880
# The number runs:  -881
# The number runs:  -882
# The number runs:  -883
# The number runs:  -884
# The number runs:  -885
# The number runs:  -886
# The number runs:  -887
# The number runs:  -888
# The number runs:  -889
# The number runs:  -890
# The number runs:  -891
# The number runs:  -892
# The number runs:  -893
# The number runs:  -894
# The number runs:  -895
# The number runs:  -896
# The number runs:  -897
# The number runs:  -898
# The number runs:  -899
# The number runs:  -900
# The number runs:  -901
# The number runs:  -902
# The number runs:  -903
# The number runs:  -904
# The number runs:  -905
# The number runs:  -906
# The number runs:  -907
# The number runs:  -908
# The number runs:  -909
# The number runs:  -910
# The number runs:  -911
# The number runs:  -912
# The number runs:  -913
# The number runs:  -914
# The number runs:  -915
# The number runs:  -916
# The number runs:  -917
# The number runs:  -918
# The number runs:  -919
# The number runs:  -920
# The number runs:  -921
# The number runs:  -922
# The number runs:  -923
# The number runs:  -924
# The number runs:  -925
# The number runs:  -926
# The number runs:  -927
# The number runs:  -928
# The number runs:  -929
# The number runs:  -930
# The number runs:  -931
# The number runs:  -932
# The number runs:  -933
# The number runs:  -934
# The number runs:  -935
# The number runs:  -936
# The number runs:  -937
# The number runs:  -938
# The number runs:  -939
# The number runs:  -940
# The number runs:  -941
# The number runs:  -942
# The number runs:  -943
# The number runs:  -944
# The number runs:  -945
# The number runs:  -946
# The number runs:  -947
# The number runs:  -948
# The number runs:  -949
# The number runs:  -950
# The number runs:  -951
# The number runs:  -952
# The number runs:  -953
# The number runs:  -954
# The number runs:  -955
# The number runs:  -956
# The number runs:  -957
# The number runs:  -958
# The number runs:  -959
# The number runs:  -960
# The number runs:  -961
# The number runs:  -962
# The number runs:  -963
# The number runs:  -964
# The number runs:  -965
# The number runs:  -966
# The number runs:  -967
# The number runs:  -968
# The number runs:  -969
# The number runs:  -970
# The number runs:  -971
# The number runs:  -972
# The number runs:  -973
# The number runs:  -974
# The number runs:  -975
# The number runs:  -976
# The number runs:  -977
# The number runs:  -978
# The number runs:  -979
# The number runs:  -980
# The number runs:  -981
# The number runs:  -982
# The number runs:  -983
# The number runs:  -984
# The number runs:  -985
# The number runs:  -986
# The number runs:  -987
# The number runs:  -988
# The number runs:  -989
# The number runs:  -990
# The number runs:  -991
# The number runs:  -992
# The number runs:  -993
# The number runs:  -994
# The number runs:  -995
# The number runs:  -996
# The number runs:  -997
# The number runs:  -998
# The number runs:  -999
# The number runs:  -1000
# The number runs:  -1001
# The number runs:  -1002
# The number runs:  -1003
# The number runs:  -1004
# The number runs:  -1005
# The number runs:  -1006
# The number runs:  -1007
# The number runs:  -1008
# The number runs:  -1009
# The number runs:  -1010
# The number runs:  -1011
# The number runs:  -1012
# The number runs:  -1013
# The number runs:  -1014
# The number runs:  -1015
# The number runs:  -1016
# The number runs:  -1017
# The number runs:  -1018
# The number runs:  -1019
# The number runs:  -1020
# The number runs:  -1021
# The number runs:  -1022
# The number runs:  -1023
# The number runs:  -1024
# The number runs:  -1025
# The number runs:  -1026
# The number runs:  -1027
# The number runs:  -1028
# The number runs:  -1029
# The number runs:  -1030
# The number runs:  -1031
# The number runs:  -1032
# The number runs:  -1033
# The number runs:  -1034
# The number runs:  -1035
# The number runs:  -1036
# The number runs:  -1037
# The number runs:  -1038
# The number runs:  -1039
# The number runs:  -1040
# The number runs:  -1041
# The number runs:  -1042
# The number runs:  -1043
# The number runs:  -1044
# The number runs:  -1045
# The number runs:  -1046
# The number runs:  -1047
# The number runs:  -1048
# The number runs:  -1049
# The number runs:  -1050
# The number runs:  -1051
# The number runs:  -1052
# The number runs:  -1053
# The number runs:  -1054
# The number runs:  -1055
# The number runs:  -1056
# The number runs:  -1057
# The number runs:  -1058
# The number runs:  -1059
# The number runs:  -1060
# The number runs:  -1061
# The number runs:  -1062
# The number runs:  -1063
# The number runs:  -1064
# The number runs:  -1065
# The number runs:  -1066
# The number runs:  -1067
# The number runs:  -1068
# The number runs:  -1069
# The number runs:  -1070
# The number runs:  -1071
# The number runs:  -1072
# The number runs:  -1073
# The number runs:  -1074
# The number runs:  -1075
# The number runs:  -1076
# The number runs:  -1077
# The number runs:  -1078
# The number runs:  -1079
# The number runs:  -1080
# The number runs:  -1081
# The number runs:  -1082
# The number runs:  -1083
# The number runs:  -1084
# The number runs:  -1085
# The number runs:  -1086
# The number runs:  -1087
# The number runs:  -1088
# The number runs:  -1089
# The number runs:  -1090
# The number runs:  -1091
# The number runs:  -1092
# The number runs:  -1093
# The number runs:  -1094
# The number runs:  -1095
# The number runs:  -1096
# The number runs:  -1097
# The number runs:  -1098
# The number runs:  -1099
# The number runs:  -1100
# The number runs:  -1101
# The number runs:  -1102
# The number runs:  -1103
# The number runs:  -1104
# The number runs:  -1105
# The number runs:  -1106
# The number runs:  -1107
# The number runs:  -1108
# The number runs:  -1109
# The number runs:  -1110
# The number runs:  -1111
# The number runs:  -1112
# The number runs:  -1113
# The number runs:  -1114
# The number runs:  -1115
# The number runs:  -1116
# The number runs:  -1117
# The number runs:  -1118
# The number runs:  -1119
# The number runs:  -1120
# The number runs:  -1121
# The number runs:  -1122
# The number runs:  -1123
# The number runs:  -1124
# The number runs:  -1125
# The number runs:  -1126
# The number runs:  -1127
# The number runs:  -1128
# The number runs:  -1129
# The number runs:  -1130
# The number runs:  -1131
# The number runs:  -1132
# The number runs:  -1133
# The number runs:  -1134
# The number runs:  -1135
# The number runs:  -1136
# The number runs:  -1137
# The number runs:  -1138
# The number runs:  -1139
# The number runs:  -1140
# The number runs:  -1141
# The number runs:  -1142
# The number runs:  -1143
# The number runs:  -1144
# The number runs:  -1145
# The number runs:  -1146
# The number runs:  -1147
# The number runs:  -1148
# The number runs:  -1149
# The number runs:  -1150
# The number runs:  -1151
# The number runs:  -1152
# The number runs:  -1153
# The number runs:  -1154
# The number runs:  -1155
# The number runs:  -1156
# The number runs:  -1157
# The number runs:  -1158
# The number runs:  -1159
# The number runs:  -1160
# The number runs:  -1161
# The number runs:  -1162
# The number runs:  -1163
# The number runs:  -1164
# The number runs:  -1165
# The number runs:  -1166
# The number runs:  -1167
# The number runs:  -1168
# The number runs:  -1169
# The number runs:  -1170
# The number runs:  -1171
# The number runs:  -1172
# The number runs:  -1173
# The number runs:  -1174
# The number runs:  -1175
# The number runs:  -1176
# The number runs:  -1177
# The number runs:  -1178
# The number runs:  -1179
# The number runs:  -1180
# The number runs:  -1181
# The number runs:  -1182
# The number runs:  -1183
# The number runs:  -1184
# The number runs:  -1185
# The number runs:  -1186
# The number runs:  -1187
# The number runs:  -1188
# The number runs:  -1189
# The number runs:  -1190
# The number runs:  -1191
# The number runs:  -1192
# The number runs:  -1193
# The number runs:  -1194
# The number runs:  -1195
# The number runs:  -1196
# The number runs:  -1197
# The number runs:  -1198
# The number runs:  -1199
# The number runs:  -1200
# The number runs:  -1201
# The number runs:  -1202
# The number runs:  -1203
# The number runs:  -1204
# The number runs:  -1205
# The number runs:  -1206
# The number runs:  -1207
# The number runs:  -1208
# The number runs:  -1209
# The number runs:  -1210
# The number runs:  -1211
# The number runs:  -1212
# The number runs:  -1213
# The number runs:  -1214
# The number runs:  -1215
# The number runs:  -1216
# The number runs:  -1217
# The number runs:  -1218
# The number runs:  -1219
# The number runs:  -1220
# The number runs:  -1221
# The number runs:  -1222
# The number runs:  -1223
# The number runs:  -1224
# The number runs:  -1225
# The number runs:  -1226
# The number runs:  -1227
# The number runs:  -1228
# The number runs:  -1229
# The number runs:  -1230
# The number runs:  -1231
# The number runs:  -1232
# The number runs:  -1233
# The number runs:  -1234
# The number runs:  -1235
# The number runs:  -1236
# The number runs:  -1237
# The number runs:  -1238
# The number runs:  -1239
# The number runs:  -1240
# The number runs:  -1241
# The number runs:  -1242
# The number runs:  -1243
# The number runs:  -1244
# The number runs:  -1245
# The number runs:  -1246
# The number runs:  -1247
# The number runs:  -1248
# The number runs:  -1249
# The number runs:  -1250
# The number runs:  -1251
# The number runs:  -1252
# The number runs:  -1253
# The number runs:  -1254
# The number runs:  -1255
# The number runs:  -1256
# The number runs:  -1257
# The number runs:  -1258
# The number runs:  -1259
# The number runs:  -1260
# The number runs:  -1261
# The number runs:  -1262
# The number runs:  -1263
# The number runs:  -1264
# The number runs:  -1265
# The number runs:  -1266
# The number runs:  -1267
# The number runs:  -1268
# The number runs:  -1269
# The number runs:  -1270
# The number runs:  -1271
# The number runs:  -1272
# The number runs:  -1273
# The number runs:  -1274
# The number runs:  -1275
# The number runs:  -1276
# The number runs:  -1277
# The number runs:  -1278
# The number runs:  -1279
# The number runs:  -1280
# The number runs:  -1281
# The number runs:  -1282
# The number runs:  -1283
# The number runs:  -1284
# The number runs:  -1285
# The number runs:  -1286
# The number runs:  -1287
# The number runs:  -1288
# The number runs:  -1289
# The number runs:  -1290
# The number runs:  -1291
# The number runs:  -1292
# The number runs:  -1293
# The number runs:  -1294
# The number runs:  -1295
# The number runs:  -1296
# The number runs:  -1297
# The number runs:  -1298
# The number runs:  -1299
# The number runs:  -1300
# The number runs:  -1301
# The number runs:  -1302
# The number runs:  -1303
# The number runs:  -1304
# The number runs:  -1305
# The number runs:  -1306
# The number runs:  -1307
# The number runs:  -1308
# The number runs:  -1309
# The number runs:  -1310
# The number runs:  -1311
# The number runs:  -1312
# The number runs:  -1313
# The number runs:  -1314
# The number runs:  -1315
# The number runs:  -1316
# The number runs:  -1317
# The number runs:  -1318
# The number runs:  -1319
# The number runs:  -1320
# The number runs:  -1321
# The number runs:  -1322
# The number runs:  -1323
# The number runs:  -1324
# The number runs:  -1325
# The number runs:  -1326
# The number runs:  -1327
# The number runs:  -1328
# The number runs:  -1329
# The number runs:  -1330
# The number runs:  -1331
# The number runs:  -1332
# The number runs:  -1333
# The number runs:  -1334
# The number runs:  -1335
# The number runs:  -1336
# The number runs:  -1337
# The number runs:  -1338
# The number runs:  -1339
# The number runs:  -1340
# The number runs:  -1341
# The number runs:  -1342
# The number runs:  -1343
# The number runs:  -1344
# The number runs:  -1345
# The number runs:  -1346
# The number runs:  -1347
# The number runs:  -1348
# The number runs:  -1349
# The number runs:  -1350
# The number runs:  -1351
# The number runs:  -1352
# The number runs:  -1353
# The number runs:  -1354
# The number runs:  -1355
# The number runs:  -1356
# The number runs:  -1357
# The number runs:  -1358
# The number runs:  -1359
# The number runs:  -1360
# The number runs:  -1361
# The number runs:  -1362
# The number runs:  -1363
# The number runs:  -1364
# The number runs:  -1365
# The number runs:  -1366
# The number runs:  -1367
# The number runs:  -1368
# The number runs:  -1369
# The number runs:  -1370
# The number runs:  -1371
# The number runs:  -1372
# The number runs:  -1373
# The number runs:  -1374
# The number runs:  -1375
# The number runs:  -1376
# The number runs:  -1377
# The number runs:  -1378
# The number runs:  -1379
# The number runs:  -1380
# The number runs:  -1381
# The number runs:  -1382
# The number runs:  -1383
# The number runs:  -1384
# The number runs:  -1385
# The number runs:  -1386
# The number runs:  -1387
# The number runs:  -1388
# The number runs:  -1389
# The number runs:  -1390
# The number runs:  -1391
# The number runs:  -1392
# The number runs:  -1393
# The number runs:  -1394
# The number runs:  -1395
# The number runs:  -1396
# The number runs:  -1397
# The number runs:  -1398
# The number runs:  -1399
# The number runs:  -1400
# The number runs:  -1401
# The number runs:  -1402
# The number runs:  -1403
# The number runs:  -1404
# The number runs:  -1405
# The number runs:  -1406
# The number runs:  -1407
# The number runs:  -1408
# The number runs:  -1409
# The number runs:  -1410
# The number runs:  -1411
# The number runs:  -1412
# The number runs:  -1413
# The number runs:  -1414
# The number runs:  -1415
# The number runs:  -1416
# The number runs:  -1417
# The number runs:  -1418
# The number runs:  -1419
# The number runs:  -1420
# The number runs:  -1421
# The number runs:  -1422
# The number runs:  -1423
# The number runs:  -1424
# The number runs:  -1425
# The number runs:  -1426
# The number runs:  -1427
# The number runs:  -1428
# The number runs:  -1429
# The number runs:  -1430
# The number runs:  -1431
# The number runs:  -1432
# The number runs:  -1433
# The number runs:  -1434
# The number runs:  -1435
# The number runs:  -1436
# The number runs:  -1437
# The number runs:  -1438
# The number runs:  -1439
# The number runs:  -1440
# The number runs:  -1441
# The number runs:  -1442
# The number runs:  -1443
# The number runs:  -1444
# The number runs:  -1445
# The number runs:  -1446
# The number runs:  -1447
# The number runs:  -1448
# The number runs:  -1449
# The number runs:  -1450
# The number runs:  -1451
# The number runs:  -1452
# The number runs:  -1453
# The number runs:  -1454
# The number runs:  -1455
# The number runs:  -1456
# The number runs:  -1457
# The number runs:  -1458
# The number runs:  -1459
# The number runs:  -1460
# The number runs:  -1461
# The number runs:  -1462
# The number runs:  -1463
# The number runs:  -1464
# The number runs:  -1465
# The number runs:  -1466
# The number runs:  -1467
# The number runs:  -1468
# The number runs:  -1469
# The number runs:  -1470
# The number runs:  -1471
# The number runs:  -1472
# The number runs:  -1473
# The number runs:  -1474
# The number runs:  -1475
# The number runs:  -1476
# The number runs:  -1477
# The number runs:  -1478
# The number runs:  -1479
# The number runs:  -1480
# The number runs:  -1481
# The number runs:  -1482
# The number runs:  -1483
# The number runs:  -1484
# The number runs:  -1485
# The number runs:  -1486
# The number runs:  -1487
# The number runs:  -1488
# The number runs:  -1489
# The number runs:  -1490
# The number runs:  -1491
# The number runs:  -1492
# The number runs:  -1493
# The number runs:  -1494
# The number runs:  -1495
# The number runs:  -1496
# The number runs:  -1497
# The number runs:  -1498
# The number runs:  -1499
# The number runs:  -1500
# The number runs:  -1501
# The number runs:  -1502
# The number runs:  -1503
# The number runs:  -1504
# The number runs:  -1505
# The number runs:  -1506
# The number runs:  -1507
# The number runs:  -1508
# The number runs:  -1509
# The number runs:  -1510
# The number runs:  -1511
# The number runs:  -1512
# The number runs:  -1513
# The number runs:  -1514
# The number runs:  -1515
# The number runs:  -1516
# The number runs:  -1517
# The number runs:  -1518
# The number runs:  -1519
# The number runs:  -1520
# The number runs:  -1521
# The number runs:  -1522
# The number runs:  -1523
# The number runs:  -1524
# The number runs:  -1525
# The number runs:  -1526
# The number runs:  -1527
# The number runs:  -1528
# The number runs:  -1529
# The number runs:  -1530
# The number runs:  -1531
# The number runs:  -1532
# The number runs:  -1533
# The number runs:  -1534
# The number runs:  -1535
# The number runs:  -1536
# The number runs:  -1537
# The number runs:  -1538
# The number runs:  -1539
# The number runs:  -1540
# The number runs:  -1541
# The number runs:  -1542
# The number runs:  -1543
# The number runs:  -1544
# The number runs:  -1545
# The number runs:  -1546
# The number runs:  -1547
# The number runs:  -1548
# The number runs:  -1549
# The number runs:  -1550
# The number runs:  -1551
# The number runs:  -1552
# The number runs:  -1553
# The number runs:  -1554
# The number runs:  -1555
# The number runs:  -1556
# The number runs:  -1557
# The number runs:  -1558
# The number runs:  -1559
# The number runs:  -1560
# The number runs:  -1561
# The number runs:  -1562
# The number runs:  -1563
# The number runs:  -1564
# The number runs:  -1565
# The number runs:  -1566
# The number runs:  -1567
# The number runs:  -1568
# The number runs:  -1569
# The number runs:  -1570
# The number runs:  -1571
# The number runs:  -1572
# The number runs:  -1573
# The number runs:  -1574
# The number runs:  -1575
# The number runs:  -1576
# The number runs:  -1577
# The number runs:  -1578
# The number runs:  -1579
# The number runs:  -1580
# The number runs:  -1581
# The number runs:  -1582
# The number runs:  -1583
# The number runs:  -1584
# The number runs:  -1585
# The number runs:  -1586
# The number runs:  -1587
# The number runs:  -1588
# The number runs:  -1589
# The number runs:  -1590
# The number runs:  -1591
# The number runs:  -1592
# The number runs:  -1593
# The number runs:  -1594
# The number runs:  -1595
# The number runs:  -1596
# The number runs:  -1597
# The number runs:  -1598
# The number runs:  -1599
# The number runs:  -1600
# The number runs:  -1601
# The number runs:  -1602
# The number runs:  -1603
# The number runs:  -1604
# The number runs:  -1605
# The number runs:  -1606
# The number runs:  -1607
# The number runs:  -1608
# The number runs:  -1609
# The number runs:  -1610
# The number runs:  -1611
# The number runs:  -1612
# The number runs:  -1613
# The number runs:  -1614
# The number runs:  -1615
# The number runs:  -1616
# The number runs:  -1617
# The number runs:  -1618
# The number runs:  -1619
# The number runs:  -1620
# The number runs:  -1621
# The number runs:  -1622
# The number runs:  -1623
# The number runs:  -1624
# The number runs:  -1625
# The number runs:  -1626
# The number runs:  -1627
# The number runs:  -1628
# The number runs:  -1629
# The number runs:  -1630
# The number runs:  -1631
# The number runs:  -1632
# The number runs:  -1633
# The number runs:  -1634
# The number runs:  -1635
# The number runs:  -1636
# The number runs:  -1637
# The number runs:  -1638
# The number runs:  -1639
# The number runs:  -1640
# The number runs:  -1641
# The number runs:  -1642
# The number runs:  -1643
# The number runs:  -1644
# The number runs:  -1645
# The number runs:  -1646
# The number runs:  -1647
# The number runs:  -1648
# The number runs:  -1649
# The number runs:  -1650
# The number runs:  -1651
# The number runs:  -1652
# The number runs:  -1653
# The number runs:  -1654
# The number runs:  -1655
# The number runs:  -1656
# The number runs:  -1657
# The number runs:  -1658
# The number runs:  -1659
# The number runs:  -1660
# The number runs:  -1661
# The number runs:  -1662
# The number runs:  -1663
# The number runs:  -1664
# The number runs:  -1665
# The number runs:  -1666
# The number runs:  -1667
# The number runs:  -1668
# The number runs:  -1669
# The number runs:  -1670
# The number runs:  -1671
# The number runs:  -1672
# The number runs:  -1673
# The number runs:  -1674
# The number runs:  -1675
# The number runs:  -1676
# The number runs:  -1677
# The number runs:  -1678
# The number runs:  -1679
# The number runs:  -1680
# The number runs:  -1681
# The number runs:  -1682
# The number runs:  -1683
# The number runs:  -1684
# The number runs:  -1685
# The number runs:  -1686
# The number runs:  -1687
# The number runs:  -1688
# The number runs:  -1689
# The number runs:  -1690
# The number runs:  -1691
# The number runs:  -1692
# The number runs:  -1693
# The number runs:  -1694
# The number runs:  -1695
# The number runs:  -1696
# The number runs:  -1697
# The number runs:  -1698
# The number runs:  -1699
# The number runs:  -1700
# The number runs:  -1701
# The number runs:  -1702
# The number runs:  -1703
# The number runs:  -1704
# The number runs:  -1705
# The number runs:  -1706
# The number runs:  -1707
# The number runs:  -1708
# The number runs:  -1709
# The number runs:  -1710
# The number runs:  -1711
# The number runs:  -1712
# The number runs:  -1713
# The number runs:  -1714
# The number runs:  -1715
# The number runs:  -1716
# The number runs:  -1717
# The number runs:  -1718
# The number runs:  -1719
# The number runs:  -1720
# The number runs:  -1721
# The number runs:  -1722
# The number runs:  -1723
# The number runs:  -1724
# The number runs:  -1725
# The number runs:  -1726
# The number runs:  -1727
# The number runs:  -1728
# The number runs:  -1729
# The number runs:  -1730
# The number runs:  -1731
# The number runs:  -1732
# The number runs:  -1733
# The number runs:  -1734
# The number runs:  -1735
# The number runs:  -1736
# The number runs:  -1737
# The number runs:  -1738
# The number runs:  -1739
# The number runs:  -1740
# The number runs:  -1741
# The number runs:  -1742
# The number runs:  -1743
# The number runs:  -1744
# The number runs:  -1745
# The number runs:  -1746
# The number runs:  -1747
# The number runs:  -1748
# The number runs:  -1749
# The number runs:  -1750
# The number runs:  -1751
# The number runs:  -1752
# The number runs:  -1753
# The number runs:  -1754
# The number runs:  -1755
# The number runs:  -1756
# The number runs:  -1757
# The number runs:  -1758
# The number runs:  -1759
# The number runs:  -1760
# The number runs:  -1761
# The number runs:  -1762
# The number runs:  -1763
# The number runs:  -1764
# The number runs:  -1765
# The number runs:  -1766
# The number runs:  -1767
# The number runs:  -1768
# The number runs:  -1769
# The number runs:  -1770
# The number runs:  -1771
# The number runs:  -1772
# The number runs:  -1773
# The number runs:  -1774
# The number runs:  -1775
# The number runs:  -1776
# The number runs:  -1777
# The number runs:  -1778
# The number runs:  -1779
# The number runs:  -1780
# The number runs:  -1781
# The number runs:  -1782
# The number runs:  -1783
# The number runs:  -1784
# The number runs:  -1785
# The number runs:  -1786
# The number runs:  -1787
# The number runs:  -1788
# The number runs:  -1789
# The number runs:  -1790
# The number runs:  -1791
# The number runs:  -1792
# The number runs:  -1793
# The number runs:  -1794
# The number runs:  -1795
# The number runs:  -1796
# The number runs:  -1797
# The number runs:  -1798
# The number runs:  -1799
# The number runs:  -1800
# The number runs:  -1801
# The number runs:  -1802
# The number runs:  -1803
# The number runs:  -1804
# The number runs:  -1805
# The number runs:  -1806
# The number runs:  -1807
# The number runs:  -1808
# The number runs:  -1809
# The number runs:  -1810
# The number runs:  -1811
# The number runs:  -1812
# The number runs:  -1813
# The number runs:  -1814
# The number runs:  -1815
# The number runs:  -1816
# The number runs:  -1817
# The number runs:  -1818
# The number runs:  -1819
# The number runs:  -1820
# The number runs:  -1821
# The number runs:  -1822
# The number runs:  -1823
# The number runs:  -1824
# The number runs:  -1825
# The number runs:  -1826
# The number runs:  -1827
# The number runs:  -1828
# The number runs:  -1829
# The number runs:  -1830
# The number runs:  -1831
# The number runs:  -1832
# The number runs:  -1833
# The number runs:  -1834
# The number runs:  -1835
# The number runs:  -1836
# The number runs:  -1837
# The number runs:  -1838
# The number runs:  -1839
# The number runs:  -1840
# The number runs:  -1841
# The number runs:  -1842
# The number runs:  -1843
# The number runs:  -1844
# The number runs:  -1845
# The number runs:  -1846
# The number runs:  -1847
# The number runs:  -1848
# The number runs:  -1849
# The number runs:  -1850
# The number runs:  -1851
# The number runs:  -1852
# The number runs:  -1853
# The number runs:  -1854
# The number runs:  -1855
# The number runs:  -1856
# The number runs:  -1857
# The number runs:  -1858
# The number runs:  -1859
# The number runs:  -1860
# The number runs:  -1861
# The number runs:  -1862
# The number runs:  -1863
# The number runs:  -1864
# The number runs:  -1865
# The number runs:  -1866
# The number runs:  -1867
# The number runs:  -1868
# The number runs:  -1869
# The number runs:  -1870
# The number runs:  -1871
# The number runs:  -1872
# The number runs:  -1873
# The number runs:  -1874
# The number runs:  -1875
# The number runs:  -1876
# The number runs:  -1877
# The number runs:  -1878
# The number runs:  -1879
# The number runs:  -1880
# The number runs:  -1881
# The number runs:  -1882
# The number runs:  -1883
# The number runs:  -1884
# The number runs:  -1885
# The number runs:  -1886
# The number runs:  -1887
# The number runs:  -1888
# The number runs:  -1889
# The number runs:  -1890
# The number runs:  -1891
# The number runs:  -1892
# The number runs:  -1893
# The number runs:  -1894
# The number runs:  -1895
# The number runs:  -1896
# The number runs:  -1897
# The number runs:  -1898
# The number runs:  -1899
# The number runs:  -1900
# The number runs:  -1901
# The number runs:  -1902
# The number runs:  -1903
# The number runs:  -1904
# The number runs:  -1905
# The number runs:  -1906
# The number runs:  -1907
# The number runs:  -1908
# The number runs:  -1909
# The number runs:  -1910
# The number runs:  -1911
# The number runs:  -1912
# The number runs:  -1913
# The number runs:  -1914
# The number runs:  -1915
# The number runs:  -1916
# The number runs:  -1917
# The number runs:  -1918
# The number runs:  -1919
# The number runs:  -1920
# The number runs:  -1921
# The number runs:  -1922
# The number runs:  -1923
# The number runs:  -1924
# The number runs:  -1925
# The number runs:  -1926
# The number runs:  -1927
# The number runs:  -1928
# The number runs:  -1929
# The number runs:  -1930
# The number runs:  -1931
# The number runs:  -1932
# The number runs:  -1933
# The number runs:  -1934
# The number runs:  -1935
# The number runs:  -1936
# The number runs:  -1937
# The number runs:  -1938
# The number runs:  -1939
# The number runs:  -1940
# The number runs:  -1941
# The number runs:  -1942
# The number runs:  -1943
# The number runs:  -1944
# The number runs:  -1945
# The number runs:  -1946
# The number runs:  -1947
# The number runs:  -1948
# The number runs:  -1949
# The number runs:  -1950
# The number runs:  -1951
# The number runs:  -1952
# The number runs:  -1953
# The number runs:  -1954
# The number runs:  -1955
# The number runs:  -1956
# The number runs:  -1957
# The number runs:  -1958
# The number runs:  -1959
# The number runs:  -1960
# The number runs:  -1961
# The number runs:  -1962
# The number runs:  -1963
# The number runs:  -1964
# The number runs:  -1965
# The number runs:  -1966
# The number runs:  -1967
# The number runs:  -1968
# The number runs:  -1969
# The number runs:  -1970
# The number runs:  -1971
# The number runs:  -1972
# The number runs:  -1973
# The number runs:  -1974
# The number runs:  -1975
# The number runs:  -1976
# The number runs:  -1977
# The number runs:  -1978
# The number runs:  -1979
# The number runs:  -1980
# The number runs:  -1981
# The number runs:  -1982
# The number runs:  -1983
# The number runs:  -1984
# The number runs:  -1985
# The number runs:  -1986
# The number runs:  -1987
# The number runs:  -1988
# The number runs:  -1989
# The number runs:  -1990
# The number runs:  -1991
# The number runs:  -1992
# The number runs:  -1993
# The number runs:  -1994
# The number runs:  -1995
# The number runs:  -1996
# The number runs:  -1997
# The number runs:  -1998
# The number runs:  -1999
# The number runs:  -2000
# The number runs:  -2001
# The number runs:  -2002
# The number runs:  -2003
# The number runs:  -2004
# The number runs:  -2005
# The number runs:  -2006
# The number runs:  -2007
# The number runs:  -2008
# The number runs:  -2009
# The number runs:  -2010
# The number runs:  -2011
# The number runs:  -2012
# The number runs:  -2013
# The number runs:  -2014
# The number runs:  -2015
# The number runs:  -2016
# The number runs:  -2017
# The number runs:  -2018
# The number runs:  -2019
# The number runs:  -2020
# The number runs:  -2021
# The number runs:  -2022
# The number runs:  -2023
# The number runs:  -2024
# The number runs:  -2025
# The number runs:  -2026
# The number runs:  -2027
# The number runs:  -2028
# The number runs:  -2029
# The number runs:  -2030
# The number runs:  -2031
# The number runs:  -2032
# The number runs:  -2033
# The number runs:  -2034
# The number runs:  -2035
# The number runs:  -2036
# The number runs:  -2037
# The number runs:  -2038
# The number runs:  -2039
# The number runs:  -2040
# The number runs:  -2041
# ...
# The number runs:  -2388
# The number runs:  -2389
# The number runs:  -2390
# The number runs:  -2391
# The number runs:  -2392
# The number runs:  -2393
# The number runs:  -2394
# The number runs:  -2395
# The number runs:  -2396
# The number runs:  -2397
# The number runs:  -2398
# The number runs:  -2399
# The number runs:  -2400
# The number runs:  -2401
# The number runs:  -2402
# The number runs:  -2403
# The number runs:  -2404
# The number runs:  -2405
# The number runs:  -2406
# The number runs:  -2407
# The number runs:  -2408
# The number runs:  -2409
# The number runs:  -2410
# The number runs:  -2411
# The number runs:  -2412
# The number runs:  -2413
# The number runs:  -2414
# The number runs:  -2415
# The number runs:  -2416
# The number runs:  -2417
# The number runs:  -2418
# The number runs:  -2419
# The number runs:  -2420
# The number runs:  -2421
# The number runs:  -2422
# The number runs:  -2423
# The number runs:  -2424
# The number runs:  -2425
# The number runs:  -2426
# The number runs:  -2427
# The number runs:  -2428
# The number runs:  -2429
# The number runs:  -2430
# The number runs:  -2431
# The number runs:  -2432
# The number runs:  -2433
# The number runs:  -2434
# The number runs:  -2435
# The number runs:  -2436
# The number runs:  -2437
# The number runs:  -2438
# The number runs:  -2439
# The number runs:  -2440
# The number runs:  -2441
# The number runs:  -2442
# The number runs:  -2443
# The number runs:  -2444
# The number runs:  -2445
# The number runs:  -2446
# The number runs:  -2447
# The number runs:  -2448
# The number runs:  -2449
# The number runs:  -2450
# The number runs:  -2451
# The number runs:  -2452
# The number runs:  -2453
# The number runs:  -2454
# The number runs:  -2455
# The number runs:  -2456
# The number runs:  -2457
# The number runs:  -2458
# The number runs:  -2459
# The number runs:  -2460
# The number runs:  -2461
# The number runs:  -2462
# The number runs:  -2463
# The number runs:  -2464
# The number runs:  -2465
# The number runs:  -2466
# The number runs:  -2467
# The number runs:  -2468
# The number runs:  -2469
# The number runs:  -2470
# The number runs:  -2471
# The number runs:  -2472
# The number runs:  -2473
# The number runs:  -2474
# The number runs:  -2475
# The number runs:  -2476
# The number runs:  -2477
# The number runs:  -2478
# The number runs:  -2479
# The number runs:  -2480
# The number runs:  -2481
# The number runs:  -2482
# The number runs:  -2483
# The number runs:  -2484
# The number runs:  -2485
# The number runs:  -2486
# The number runs:  -2487
# The number runs:  -2488
# The number runs:  -2489
# The number runs:  -2490
# The number runs:  -2491
# The number runs:  -2492
# The number runs:  -2493
# The number runs:  -2494
# The number runs:  -2495
# The number runs:  -2496
# The number runs:  -2497
# The number runs:  -2498
# The number runs:  -2499
# The number runs:  -2500
# The number runs:  -2501
# The number runs:  -2502
# The number runs:  -2503
# The number runs:  -2504
# The number runs:  -2505
# The number runs:  -2506
# The number runs:  -2507
# The number runs:  -2508
# The number runs:  -2509
# The number runs:  -2510
# The number runs:  -2511
# The number runs:  -2512
# The number runs:  -2513
# The number runs:  -2514
# The number runs:  -2515
# The number runs:  -2516
# The number runs:  -2517
# The number runs:  -2518
# The number runs:  -2519
# The number runs:  -2520
# The number runs:  -2521
# The number runs:  -2522
# The number runs:  -2523
# The number runs:  -2524
# The number runs:  -2525
# The number runs:  -2526
# The number runs:  -2527
# The number runs:  -2528
# The number runs:  -2529
# The number runs:  -2530
# The number runs:  -2531
# The number runs:  -2532
# The number runs:  -2533
# The number runs:  -2534
# The number runs:  -2535
# The number runs:  -2536
# The number runs:  -2537
# The number runs:  -2538
# The number runs:  -2539
# The number runs:  -2540
# The number runs:  -2541
# The number runs:  -2542
# The number runs:  -2543
# The number runs:  -2544
# The number runs:  -2545
# The number runs:  -2546
# The number runs:  -2547
# The number runs:  -2548
# The number runs:  -2549
# The number runs:  -2550
# The number runs:  -2551
# The number runs:  -2552
# The number runs:  -2553
# The number runs:  -2554
# The number runs:  -2555
# The number runs:  -2556
# The number runs:  -2557
# The number runs:  -2558
# The number runs:  -2559
# The number runs:  -2560
# The number runs:  -2561
# The number runs:  -2562
# The number runs:  -2563
# The number runs:  -2564
# The number runs:  -2565
# The number runs:  -2566
# The number runs:  -2567
# The number runs:  -2568
# The number runs:  -2569
# The number runs:  -2570
# The number runs:  -2571
# The number runs:  -2572
# The number runs:  -2573
# The number runs:  -2574
# The number runs:  -2575
# The number runs:  -2576
# The number runs:  -2577
# The number runs:  -2578
# The number runs:  -2579
# The number runs:  -2580
# The number runs:  -2581
# The number runs:  -2582
# The number runs:  -2583
# The number runs:  -2584
# The number runs:  -2585
# The number runs:  -2586
# The number runs:  -2587
# The number runs:  -2588
# The number runs:  -2589
# The number runs:  -2590
# The number runs:  -2591
# The number runs:  -2592
# The number runs:  -2593
# The number runs:  -2594
# The number runs:  -2595
# The number runs:  -2596
# The number runs:  -2597
# The number runs:  -2598
# The number runs:  -2599
# The number runs:  -2600
# The number runs:  -2601
# The number runs:  -2602
# The number runs:  -2603
# The number runs:  -2604
# The number runs:  -2605
# The number runs:  -2606
# The number runs:  -2607
# The number runs:  -2608
# The number runs:  -2609
# The number runs:  -2610
# The number runs:  -2611
# The number runs:  -2612
# The number runs:  -2613
# The number runs:  -2614
# The number runs:  -2615
# The number runs:  -2616
# The number runs:  -2617
# The number runs:  -2618
# The number runs:  -2619
# The number runs:  -2620
# The number runs:  -2621
# The number runs:  -2622
# The number runs:  -2623
# The number runs:  -2624
# The number runs:  -2625
# The number runs:  -2626
# The number runs:  -2627
# The number runs:  -2628
# The number runs:  -2629
# The number runs:  -2630
# The number runs:  -2631
# The number runs:  -2632
# The number runs:  -2633
# The number runs:  -2634
# The number runs:  -2635
# The number runs:  -2636
# The number runs:  -2637
# The number runs:  -2638
# The number runs:  -2639
# The number runs:  -2640
# The number runs:  -2641
# The number runs:  -2642
# The number runs:  -2643
# The number runs:  -2644
# The number runs:  -2645
# The number runs:  -2646
# The number runs:  -2647
# The number runs:  -2648
# The number runs:  -2649
# The number runs:  -2650
# The number runs:  -2651
# The number runs:  -2652
# The number runs:  -2653
# The number runs:  -2654
# The number runs:  -2655
# The number runs:  -2656
# The number runs:  -2657
# The number runs:  -2658
# The number runs:  -2659
# The number runs:  -2660
# The number runs:  -2661
# The number runs:  -2662
# The number runs:  -2663
# The number runs:  -2664
# The number runs:  -2665
# The number runs:  -2666
# The number runs:  -2667
# The number runs:  -2668
# The number runs:  -2669
# The number runs:  -2670
# The number runs:  -2671
# The number runs:  -2672
# The number runs:  -2673
# The number runs:  -2674
# The number runs:  -2675
# The number runs:  -2676
# The number runs:  -2677
# The number runs:  -2678
# The number runs:  -2679
# The number runs:  -2680
# The number runs:  -2681
# The number runs:  -2682
# The number runs:  -2683
# The number runs:  -2684
# The number runs:  -2685
# The number runs:  -2686
# The number runs:  -2687
# The number runs:  -2688
# The number runs:  -2689
# The number runs:  -2690
# The number runs:  -2691
# The number runs:  -2692
# The number runs:  -2693
# The number runs:  -2694
# The number runs:  -2695
# The number runs:  -2696
# The number runs:  -2697
# The number runs:  -2698
# The number runs:  -2699
# The number runs:  -2700
# The number runs:  -2701
# The number runs:  -2702
# The number runs:  -2703
# The number runs:  -2704
# The number runs:  -2705
# The number runs:  -2706
# The number runs:  -2707
# The number runs:  -2708
# The number runs:  -2709
# The number runs:  -2710
# The number runs:  -2711
# The number runs:  -2712
# The number runs:  -2713
# The number runs:  -2714
# The number runs:  -2715
# The number runs:  -2716
# The number runs:  -2717
# The number runs:  -2718
# The number runs:  -2719
# The number runs:  -2720
# The number runs:  -2721
# The number runs:  -2722
# The number runs:  -2723
# The number runs:  -2724
# The number runs:  -2725
# The number runs:  -2726
# The number runs:  -2727
# The number runs:  -2728
# The number runs:  -2729
# The number runs:  -2730
# The number runs:  -2731
# The number runs:  -2732
# The number runs:  -2733
# The number runs:  -2734
# The number runs:  -2735
# The number runs:  -2736
# The number runs:  -2737
# The number runs:  -2738
# The number runs:  -2739
# The number runs:  -2740
# The number runs:  -2741
# The number runs:  -2742
# The number runs:  -2743
# The number runs:  -2744
# The number runs:  -2745
# The number runs:  -2746
# The number runs:  -2747
# The number runs:  -2748
# The number runs:  -2749
# The number runs:  -2750
# The number runs:  -2751
# The number runs:  -2752
# The number runs:  -2753
# The number runs:  -2754
# The number runs:  -2755
# The number runs:  -2756
# The number runs:  -2757
# The number runs:  -2758
# The number runs:  -2759
# The number runs:  -2760
# The number runs:  -2761
# The number runs:  -2762
# The number runs:  -2763
# The number runs:  -2764
# The number runs:  -2765
# The number runs:  -2766
# The number runs:  -2767
# The number runs:  -2768
# The number runs:  -2769
# The number runs:  -2770
# The number runs:  -2771
# The number runs:  -2772
# The number runs:  -2773
# The number runs:  -2774
# The number runs:  -2775
# The number runs:  -2776
# The number runs:  -2777
# The number runs:  -2778
# The number runs:  -2779
# The number runs:  -2780
# The number runs:  -2781
# The number runs:  -2782
# The number runs:  -2783
# The number runs:  -2784
# The number runs:  -2785
# The number runs:  -2786
# The number runs:  -2787
# The number runs:  -2788
# The number runs:  -2789
# The number runs:  -2790
# The number runs:  -2791
# The number runs:  -2792
# The number runs:  -2793
# The number runs:  -2794
# The number runs:  -2795
# The number runs:  -2796
# The number runs:  -2797
# The number runs:  -2798
# The number runs:  -2799
# The number runs:  -2800
# The number runs:  -2801
# The number runs:  -2802
# The number runs:  -2803
# The number runs:  -2804
# The number runs:  -2805
# The number runs:  -2806
# The number runs:  -2807
# The number runs:  -2808
# The number runs:  -2809
# The number runs:  -2810
# The number runs:  -2811
# The number runs:  -2812
# The number runs:  -2813
# The number runs:  -2814
# The number runs:  -2815
# The number runs:  -2816
# The number runs:  -2817
# The number runs:  -2818
# The number runs:  -2819
# The number runs:  -2820
# The number runs:  -2821
# The number runs:  -2822
# The number runs:  -2823
# The number runs:  -2824
# The number runs:  -2825
# The number runs:  -2826
# The number runs:  -2827
# The number runs:  -2828
# The number runs:  -2829
# The number runs:  -2830
# The number runs:  -2831
# The number runs:  -2832
# The number runs:  -2833
# The number runs:  -2834
# The number runs:  -2835
# The number runs:  -2836
# The number runs:  -2837
# The number runs:  -2838
# The number runs:  -2839
# The number runs:  -2840
# The number runs:  -2841
# The number runs:  -2842
# The number runs:  -2843
# The number runs:  -2844
# The number runs:  -2845
# The number runs:  -2846
# The number runs:  -2847
# The number runs:  -2848
# The number runs:  -2849
# The number runs:  -2850
# The number runs:  -2851
# The number runs:  -2852
# The number runs:  -2853
# The number runs:  -2854
# The number runs:  -2855
# The number runs:  -2856
# The number runs:  -2857
# The number runs:  -2858
# The number runs:  -2859
# The number runs:  -2860
# The number runs:  -2861
# The number runs:  -2862
# The number runs:  -2863
# The number runs:  -2864
# The number runs:  -2865
# The number runs:  -2866
# The number runs:  -2867
# The number runs:  -2868
# The number runs:  -2869
# The number runs:  -2870
# The number runs:  -2871
# The number runs:  -2872
# The number runs:  -2873
# The number runs:  -2874
# The number runs:  -2875
# The number runs:  -2876
# The number runs:  -2877
# The number runs:  -2878
# The number runs:  -2879
# The number runs:  -2880
# The number runs:  -2881
# The number runs:  -2882
# The number runs:  -2883
# The number runs:  -2884
# The number runs:  -2885
# The number runs:  -2886
# The number runs:  -2887
# The number runs:  -2888
# The number runs:  -2889
# The number runs:  -2890
# The number runs:  -2891
# The number runs:  -2892
# The number runs:  -2893
# The number runs:  -2894
# The number runs:  -2895
# The number runs:  -2896
# The number runs:  -2897
# The number runs:  -2898
# The number runs:  -2899
# The number runs:  -2900
# The number runs:  -2901
# The number runs:  -2902
# The number runs:  -2903
# The number runs:  -2904
# The number runs:  -2905
# The number runs:  -2906
# The number runs:  -2907
# The number runs:  -2908
# The number runs:  -2909
# The number runs:  -2910
# The number runs:  -2911
# The number runs:  -2912
# The number runs:  -2913
# The number runs:  -2914
# The number runs:  -2915
# The number runs:  -2916
# The number runs:  -2917
# The number runs:  -2918
# The number runs:  -2919
# The number runs:  -2920
# The number runs:  -2921
# The number runs:  -2922
# The number runs:  -2923
# The number runs:  -2924
# The number runs:  -2925
# The number runs:  -2926
# The number runs:  -2927
# The number runs:  -2928
# The number runs:  -2929
# The number runs:  -2930
# The number runs:  -2931
# The number runs:  -2932
# The number runs:  -2933
# The number runs:  -2934
# The number runs:  -2935
# The number runs:  -2936
# The number runs:  -2937
# The number runs:  -2938
# The number runs:  -2939
# The number runs:  -2940
# The number runs:  -2941
# The number runs:  -2942
# The number runs:  -2943
# The number runs:  -2944
# The number runs:  -2945
# The number runs:  -2946
# The number runs:  -2947
# The number runs:  -2948
# The number runs:  -2949
# The number runs:  -2950
# The number runs:  -2951
# The number runs:  -2952
# The number runs:  -2953
# The number runs:  -2954
# The number runs:  -2955
# The number runs:  -2956
# The number runs:  -2957
# The number runs:  -2958
# The number runs:  -2959
# The number runs:  -2960
# The number runs:  -2961
# The number runs:  -2962
# The number runs:  -2963
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Input In [136], in <cell line: 11>()
#       6 #     Remove this to fix maximum recursion depth error
#       7 #     if num <= 0:
#       8 #         return num
#       9     return num + my_sum_error(num - 1)
# ---> 11 my_sum_error(5)
#
# Input In [136], in my_sum_error(num)
#       4     print('The number runs: ',num)
#       6 #     Remove this to fix maximum recursion depth error
#       7 #     if num <= 0:
#       8 #         return num
# ----> 9     return num + my_sum_error(num - 1)
#
# Input In [136], in my_sum_error(num)
#       4     print('The number runs: ',num)
#       6 #     Remove this to fix maximum recursion depth error
#       7 #     if num <= 0:
#       8 #         return num
# ----> 9     return num + my_sum_error(num - 1)
#
#     [... skipping similar frames: my_sum_error at line 9 (2966 times)]
#
# Input In [136], in my_sum_error(num)
#       4     print('The number runs: ',num)
#       6 #     Remove this to fix maximum recursion depth error
#       7 #     if num <= 0:
#       8 #         return num
# ----> 9     return num + my_sum_error(num - 1)
#
# Input In [136], in my_sum_error(num)
#       3 def my_sum_error(num):
# ----> 4     print('The number runs: ',num)
#       6 #     Remove this to fix maximum recursion depth error
#       7 #     if num <= 0:
#       8 #         return num
#       9     return num + my_sum_error(num - 1)
#
# File ~/coding/coding101/data_sciences/venv_data_sciences/lib/python3.9/site-packages/ipykernel/iostream.py:549, in OutStream.write(self, string)
#     546     raise ValueError("I/O operation on closed file")
#     547 else:
# --> 549     is_child = not self._is_master_process()
#     550     # only touch the buffer in the IO thread to avoid races
#     551     with self._buffer_lock:
#
# File ~/coding/coding101/data_sciences/venv_data_sciences/lib/python3.9/site-packages/ipykernel/iostream.py:437, in OutStream._is_master_process(self)
#     436 def _is_master_process(self):
# --> 437     return os.getpid() == self._master_pid
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %%
import sys
sys.getrecursionlimit()
# Out:
# 3000
